# %% [markdown]
# ## NAME: JWEN LOBO
# ## ROLL: 37
# ## DATE: 26/02/2026
# ## SUB: MACHINE LEARNING LAB
# ##      EXP 05
# ## BATCH:02

# %%
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import accuracy_score,confusion_matrix,precision_score,recall_score,f1_score,roc_auc_score,classification_report

# %%
# Load real dataset
data = load_breast_cancer()

x = data.data
y = data.target

print("Classes:", data.target_names)
# malignant,benign

# Split data
X_train,X_test,y_train,y_test = train_test_split(x,y,test_size=0.3)
# Out:
# Classes: ['malignant' 'benign']

# %%
#
# Logistic Regression
#
lr = LogisticRegression(max_iter=5000)
lr.fit(X_train,y_train)
pred_lr = lr.predict(X_test)
print("Logistic Test Accuracy:",accuracy_score(y_test,pred_lr))
pred_dt_train=lr.predict(X_train)
print("Logistic TestAcurracy:",accuracy_score(y_test,pred_lr))
# Out:
# Logistic Test Accuracy: 0.9766081871345029
# Logistic TestAcurracy: 0.9766081871345029

# %%
#Decision Tree
#
dt = DecisionTreeClassifier()
dt.fit(X_train,y_train)
pred_dt = dt.predict(X_test)
print("Logistic Test Accuracy:",accuracy_score(y_test,pred_dt))
pred_dt_train=dt.predict(X_train)
print("Logistic TestAcurracy:",accuracy_score(y_test,pred_dt))
# Out:
# Logistic Test Accuracy: 0.9239766081871345
# Logistic TestAcurracy: 0.9239766081871345

# %%
 
knn =  KNeighborsClassifier()
knn.fit(X_train,y_train)
pred_knn = knn.predict(X_test)
print("Logistic Test Accuracy:",accuracy_score(y_test,pred_knn))
pred_knn_train=knn.predict(X_train)
print("Logistic TestAcurracy:",accuracy_score(y_test,pred_knn))
# Out:
# Logistic Test Accuracy: 0.9473684210526315
# Logistic TestAcurracy: 0.9473684210526315

# %%
 
nb = GaussianNB()
nb.fit(X_train,y_train)
pred_nb = nb.predict(X_test)
print("Logistic Test Accuracy:",accuracy_score(y_test,pred_nb))
pred_nb_train=nb.predict(X_train)
print("Logistic TestAcurracy:",accuracy_score(y_test,pred_nb))
# Out:
# Logistic Test Accuracy: 0.9239766081871345
# Logistic TestAcurracy: 0.9239766081871345

# %%
nn = MLPClassifier(max_iter=5000)
nn.fit(X_train,y_train)
pred_nn = nn.predict(X_test)
print("Logistic Test Accuracy:",accuracy_score(y_test,pred_nn))
pred_nn_train=nn.predict(X_train)
print("Logistic TestAcurracy:",accuracy_score(y_test,pred_nn))
# Out:
# Logistic Test Accuracy: 0.935672514619883
# Logistic TestAcurracy: 0.935672514619883

# %%
cm_lr=confusion_matrix(y_test,pred_lr)
print("\nLogistic Regression Confusion Matrix:")
print(cm_lr)

TN1, FP1, FN1 , TP1= cm_lr.ravel()
type1_lr=FP1/(FP1+TN1)
type2_lr=FN1/(FN1+TP1)

print("FP Type1:",FP1)
print("FN Type2:",FN1)
print("Type1 Error rate:",type1_lr*100)
print("Type2 Error rate:",type2_lr*100)
# Out:
# Logistic Regression Confusion Matrix:
# [[ 59   3]
#  [  1 108]]
# FP Type1: 3
# FN Type2: 1
# Type1 Error rate: 4.838709677419355
# Type2 Error rate: 0.9174311926605505

# %%
cm_dt=confusion_matrix(y_test,pred_lr)
print("\nLogistic Regression Confusion Matrix:")
print(cm_lr)

TN2, FP2, FN2 , TP2= cm_dt.ravel()
type1_lr=FP2/(FP2+TN2)
type2_lr=FN2/(FN2+TP2)

print("FP Type1:",FP2)
print("FN Type2:",FN2)
print("Type1 Error rate:",type1_dt*100)
print("Type2 Error rate:",type2_dt*100)
# Out:
# Logistic Regression Confusion Matrix:
# [[ 59   3]
#  [  1 108]]
# FP Type1: 3
# FN Type2: 1
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[22], line 11
#       9 print("FP Type1:",FP2)
#      10 print("FN Type2:",FN2)
# ---> 11 print("Type1 Error rate:",type1_dt*100)
#      12 print("Type2 Error rate:",type2_dt*100)
#
# NameError: name 'type1_dt' is not defined

# %%
precission1= precission1_score(y_test, pred_dt)
recall1= recall1_score(y_test, pred_dt)
f11= f1_score(y_test,pred_dt)
roc1 = roc_auc_score(y_test, pred_dt)

print("Decision Tree")
print("Precission:", precission1)
print("Recall:", recall1)
print("Fi-score:",f11)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 precission1= precission1_score(y_test, pred_dt)
#       2 recall1= recall1_score(y_test, pred_dt)
#       3 f11= f1_score(y_test,pred_dt)
#
# NameError: name 'precission1_score' is not defined
